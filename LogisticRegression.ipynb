# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Gakii/ACH/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear regression** predict a continous value
#
# **logistic regression** predict a class most used for binary classification but can be used for multiple classification

# %% [markdown]
# Logistic regression steps
#
# Z=wX+b
#
# Then apply sigmoid function to the result to obtain a number between 0 and 1
# y=σ(Z)
#
# The number we get represents the probability of input being **YES**
#
# Cross entrophy loss function is used to evaluate the model

# %% [markdown]
# **Classification and regression** are both supervised machine learning model because they use label data
#
# **Clustering** is unsupervised machine learning use unlabelled data

# %%
# !pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
import os

# %%
od.version()
# Out:
# '0.1.22'

# %%
dataset_url ="https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package"

# %%
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: gallantgakii
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package
# ...
# 100%|██████████| 3.83M/3.83M [00:00<00:00, 205MB/s]

# %%
data_dir ='/content/weather-dataset-rattle-package'

# %%
os.listdir(data_dir)
# Out:
# ['weatherAUS.csv']

# %%
train_csv = data_dir + '/weatherAUS.csv'
